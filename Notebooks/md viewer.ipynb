# %%
# !pip install grip
# Out:
# ...
#   Preparing metadata (setup.py) ... one
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   DEPRECATION: Building 'docopt' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'docopt'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=0ca2d5d68e0235bafa1d709f79d208d459bd4403cc8224f5d103be9eff649bea
#   Stored in directory: /home/prem/.cache/pip/wheels/0b/1d/03/175286677fb5a1341cc3e4755bf8ec0ed08f3329afd67446b0
# ...

# %%
# !grip README.md
# Out:
# Error: File not found: README.md

# %%
# First, let's see where we currently are
import os
print("Current working directory:", os.getcwd())

# List files in the current directory
print("\nFiles in current directory:")
# !ls

# Let's go up one directory level to check if README.md is there
print("\nGoing up one directory level...")
os.chdir('..')
print("New working directory:", os.getcwd())

# List files in the parent directory
print("\nFiles in parent directory:")
# !ls

# If you see README.md in the output, you can now run grip on it
if os.path.exists("README.md"):
    print("\nREADME.md found! Running grip...")
    # !grip README.md
else:
    print("\nREADME.md not found in this directory.")
    
    # You can search for README.md in nearby directories
    print("\nSearching for README.md in nearby directories...")
    # !find . -name "README.md" -maxdepth 3
# Out:
# Current working directory: /home/prem/UK Home Price Analysis/Average Price Analysis November 2025/Notebooks
#
# Files in current directory:
#  01_initial_exploration.ipynb		   'md viewer.ipynb'
#  02_average_price_regional_analysis.ipynb
#
# Going up one directory level...
# New working directory: /home/prem/UK Home Price Analysis/Average Price Analysis November 2025
#
# Files in parent directory:
# Data  Notebooks  README.md  Visuals
#
# README.md found! Running grip...
#  * Serving Flask app 'grip.app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://localhost:6419
# Press CTRL+C to quit
# []
# ...
